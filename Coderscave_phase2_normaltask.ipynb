# %% [markdown]
# <a href="https://colab.research.google.com/github/prithiba-A/CVIP-Internship-Coderscave/blob/main/Coderscave_phase2_normaltask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Customer Sentiment Analysis and Feedback Insights**

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer
import pandas as pd

# %%
# Download VADER lexicon
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
# Read your dataset (replace 'your_dataset.csv' with the actual file path or URL)
df = pd.read_csv('/content/purchase behaviou dataset.csv')
df
# Out:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
# [72637 rows x 3 columns]

# %%
df.head(5)
# Out:
#    LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER
# 0            1000   YOUNG SINGLES/COUPLES          Premium
# 1            1002   YOUNG SINGLES/COUPLES       Mainstream
# 2            1003          YOUNG FAMILIES           Budget
# 3            1004   OLDER SINGLES/COUPLES       Mainstream
# 4            1005  MIDAGE SINGLES/COUPLES       Mainstream

# %%
df.describe()
# Out:
#        LYLTY_CARD_NBR
# count    7.263700e+04
# mean     1.361859e+05
# std      8.989293e+04
# min      1.000000e+03
# 25%      6.620200e+04
# 50%      1.340400e+05
# 75%      2.033750e+05
# max      2.373711e+06

# %%
# Check if the necessary columns are present in the dataset
required_columns = ['LYLTY_CARD_NBR', 'LIFESTAGE', 'PREMIUM_CUSTOMER']
for col in required_columns:
    if col not in df.columns:
        raise KeyError(f"The required column '{col}' is not present in the dataset.")

# %%
# Create a synthetic 'Review' column by combining existing columns
df['Review'] = df['LYLTY_CARD_NBR'].astype(str) + ' ' + df['LIFESTAGE'] + ' ' + df['PREMIUM_CUSTOMER']

# %%
# Initialize the VADER sentiment analyzer
sia = SentimentIntensityAnalyzer()
sia

# %%
# Function to get sentiment analysis results
def get_sentiment(text):
    score = sia.polarity_scores(text)['compound']
    if score >= 0.05:
        return 'Positive'
    elif score <= -0.05:
        return 'Negative'
    else:
        return 'Neutral'

# %%
# Apply sentiment analysis to the reviews in the dataset
df['Sentiment'] = df['Review'].apply(get_sentiment)

# %%
# Display the results
print("\nSentiment Analysis Results:")
print(df[['LYLTY_CARD_NBR', 'LIFESTAGE', 'PREMIUM_CUSTOMER', 'Review', 'Sentiment']])
# Out:
# Sentiment Analysis Results:
#        LYLTY_CARD_NBR               LIFESTAGE PREMIUM_CUSTOMER  \
# 0                1000   YOUNG SINGLES/COUPLES          Premium
# 1                1002   YOUNG SINGLES/COUPLES       Mainstream
# 2                1003          YOUNG FAMILIES           Budget
# 3                1004   OLDER SINGLES/COUPLES       Mainstream
# 4                1005  MIDAGE SINGLES/COUPLES       Mainstream
# ...               ...                     ...              ...
# 72632         2370651  MIDAGE SINGLES/COUPLES       Mainstream
# 72633         2370701          YOUNG FAMILIES       Mainstream
# 72634         2370751          YOUNG FAMILIES          Premium
# 72635         2370961          OLDER FAMILIES           Budget
# 72636         2373711   YOUNG SINGLES/COUPLES       Mainstream
#
#                                           Review Sentiment
# 0             1000 YOUNG SINGLES/COUPLES Premium   Neutral
# 1          1002 YOUNG SINGLES/COUPLES Mainstream   Neutral
# ...
